# %% [markdown]
# # Metadata module from the SPARC Python Client

# %% [markdown]
# This section introduces metadata search services which query an [Elasticsearch](https://www.elastic.co) endpoint.  This endpoint contains the same metadata that powers search on the SPARC portal.  There are two basic ways to retrieve information on SPARC datasets:
#
# 1. Retrieve a full list of datasets and associated metadata
# 2. Submit a valid Elasticsearch query to retrieve selected dataset information
#
# Query results are returned as JSON in Elasticsearch format. Information on specific fields and content can be found in a [K-Core API Handbook](https://fdilab.gitbook.io/api-handbook/sparc-metadata-elasticsearch/sparc-dataset-elasticsearch-json-data-model).
#
# In order to get started, you must add information about an API Key you can register for.  Instructions for registering and receiving an API key are available as a [walk-through tutorial](https://fdilab.gitbook.io/api-handbook/sparc-k-core-api-overview/getting-started-with-sparc-apis)
#
# ### Pre-requites:
# - Python version >=3.10: as requested by the [sparc.client](https://pypi.org/project/sparc.client/) package.
# - An API Key from SciCrunch.org.Instructions for registering and receiving an API key are available as a [walk-through tutorial](https://fdilab.gitbook.io/api-handbook/sparc-k-core-api-overview/getting-started-with-sparc-apis)
# - Have a look to the [NIH SPARC Python Client doc](https://github.com/nih-sparc/sparc.client/blob/main/docs/tutorial.ipynb) as a preliminary step (and learn how to set up the Configuration).

# %% [markdown]
# ## Installation

# %% [markdown]
# The easiest way to obtain Python Sparc Client library (sparc.client) is to install the latest available version from PyPI:

# %%
# !pip install sparc.client

# %% [markdown]
# ## Setup Config File to Access Metadata Services

# %% [markdown]
# Add your API key to the config file located at config/config.ini
#
# Edit the file to include the key you registered based on instructions above:
#
# scicrunch_api_key=YOUR_API_KEY_HERE

# %% [markdown]
# ## Getting Started and Listing Datasets

# %%
# import the necessary packages
import json

from sparc.client import SparcClient

# %% [markdown]
# Now we can instantiate the client to get started

# %%
# initiate sparc.client with config file that has your API key
client = SparcClient(connect=False, config_file='../config/config.ini')

# %% [markdown]
# The following example retrieves a list of datasets and associated metadata. Getting a list of datasets will also allow you to view the JSON structure and content of the metadata.
#
# Query results are returned as JSON in Elasticsearch format. Information on specific fields and content can be found in a [K-Core API Handbook](https://fdilab.gitbook.io/api-handbook/sparc-metadata-elasticsearch/sparc-dataset-elasticsearch-json-data-model).

# %%
# Call function to list all published datasets
response = {}
response = client.metadata.list_datasets()

response
# Out:
# {'took': 7,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': 267,
#   'max_score': 1.0,
#   'hits': [{'_index': 'scr_017041-sparc_algolia_pr-ks-2022jul26',
#     '_type': 'ks',
#     '_id': '35',
#     '_score': 1.0,
#     '_ignored': ['pennsieve.versionPublishedAt.timestamp',
#      'pennsieve.revisedAt.timestamp',
#      'dates.updated.timestamp',
#      'pennsieve.firstPublishedAt.timestamp',
#      'dates.created.timestamp',
#      'pennsieve.createdAt.timestamp',
#      'pennsieve.updatedAt.timestamp'],
#     '_source': {'item': {'types': [{'name': 'dataset', 'type': 'category'}],
#       'contentTypes': [{'curie': 'ilx:0381348', 'name': 'product'}],
#       'names': [{'nameType': 'Complete Data Set',
#         'name': 'Brainstem Neuron Recording 2019'}],
#       'statistics': {'files': {'count': '164'},
#        'directory': {'count': '43'},
#        'subjects': {'count': '13'},
#        'bytes': {'count': '2208039789512'}},
#       'keywords': [{'keyword': 'swallow'},
#        {'keyword': 'superior laryngeal nerve'},
#        {'keyword': 'electrical stimulation'},
#        {'keyword': 'respiration'},
#        {'keyword': 'neural circuits'},
#        {'keyword': 'phrenic'},
#        {'keyword': 'hypoglossal'},
#        {'keyword': 'blood pressure'},
#        {'keyword': 'tracheal pressure'},
#        {'keyword': 'expired CO2'}],
#       'published': {'status': 'revision', 'boolean': 'true'},
#       'dataset': {'description': 'Simultaneously-recorded cat brainstem neuron extracellular potentials with nerves and sorted spike trains',
#        'name': 'Brainstem neuron recordings - Morris Lab USF'},
#       'readme': {'description': '**Study Purpose:** The purpose of this study was to record and evaluate the activities of individual cat brainstem neurons and nerves (phrenic, hypoglossal, vagus, RLN, and lumbar) with regard to breathing, the cardiac cycle, swallowing, electrical stimulation of the superior laryngeal/vagus nerve, and induced asthma-like conditions.\n\n**Data Collection:** This dataset contains simultaneously recorded cat brainstem neuron extracellular potentials with nerve and sorted spike trains. This dataset consists of recordings from 13 subjects. Data include recordings of extracellular neuronal activity acquired from 72-104 high-impedance tungsten microelectrodes (3-4 multielectrode arrays) positioned in the dorsomedial medulla, midline raphe region, ventral respiratory column, and the lateral tegmental field-parafacial region. These "raw" recordings are DAQ files (which have been translated into Spike2 file format). Nerve activity (e.g., phrenic, hypoglossal, lumbar, vagus, recurrent laryngeal), blood pressure, end-tidal CO2, tracheal pressure, and stimulus markers are also included in the DAQ file. File types include: .daq files, .edt files, and .smr files alongside annotation files.\n\n**Primary Conclusion:** None stated.\n\n---\n\n**Curator\'s Notes**\n\n**Experimental Design:** Subjects were decerebrated, paralyzed and artificially ventilated. Animals were anesthetized with isoflurane and arterial blood was collected and analyzed to correct metabolic acidosis as needed. Animals were infused with the neuromuscular blocker vecuronium bromide throughout the experiment to ensure paralysis. The XII nerve, Lumbar nerve, and X/RLN nerves were placed in coiled or hooked bipolar silver electrodes and used to measure the respiratory cycle and stimulus effectiveness. Experimenters used a variety of stimuli and perturbations to test different responses. Electrical stimulation to the laryngeal nerves, water bolus administration, esophageal balloon inflation and mechanical stimulation were used to elicit fictive swallowing. Amongst other tested parameters, the peripheral and central chemoreceptors were stimulated, and experimenters manipulated the subjects\' mean arterial blood pressure. After experimentation, the subjects were euthanized with an overdose of euthasol.\n\n**Completeness:** Batch\n\n**Subjects & Samples:** This study used a total of 13 cats, both male (n=1) and female (n=12), between the ages of 17-36 months (bar 1 cat whose age was unknown).\n\n**Primary vs derivative data:** This data set is composed of time series and analysis data distributed amongst three different folders. Raw data can be found in the Source folder as .daq files. Converted forms of this data is present as .smr and .xlsx files in the Primary folder, while derived version of this data is located in the Derivatives folder as .edt and .smr files.  \n\n**Important Notes:** There is a corresponding publication from a portion of this dataset. The uploaded data set includes 6 recordings from the published paper and 7 additional recordings. The published paper focused on changes in nerve activity during fictive swallowing and breathing and does not include evaluation of brainstem neuron activity.'},
#       'name': 'Feline brainstem neuron extracellular potential recordings',
#       'identifier': 'N:dataset:0a5a2827-2b39-4085-87ea-2b7fbbe27cc8',
#       'curie': 'DOI:10.26275/1upo-xvkt',
#       'modalities': [{'keyword': 'physiology'},
#        {'keyword': 'electrophysiology'}],
#       'description': 'Simultaneously recorded cat brain stem neuron extracellular potential with nerve and sorted spike trains.',
#       'docid': '35'},
#      'supportingAwards': [{'identifier': 'OT2OD023854',
#        'agency': {'name': 'National Institutes of Health'}},
#       {'agency': {'name': 'NIH SPARC Program'}}],
#      'contributors': [{'middle': {'name': 'F'},
#        'last': {'name': 'Morris'},
#        'curie': 'ORCID:0000-0001-6582-1203',
#        'name': 'Morris, Kendall F.',
#        'affiliations': [{'curie': 'ROR:032db5x82',
#          'name': 'University of South Florida',
#          'description': 'Molecular Pharmacology and Physiology\nMorsani College of Medicine\nUniversity of South Florida\nTampa, FL',
#          'uri': 'https://ror.org/032db5x82'}],
#        'uri': 'https://orcid.org/0000-0001-6582-1203',
#        'first': {'name': 'Kendall'}},
#       {'last': {'name': 'Horton'},
#        'curie': 'ORCID:0000-0002-1238-5257',
#        'name': 'Horton, Kofi-Kermit',
#        'affiliations': [{'curie': 'ROR:032db5x82',
#          'name': 'University of South Florida',
#          'description': 'Molecular Pharmacology and Physiology\nMorsani College of Medicine\nUniversity of South Florida\nTampa, FL',
#          'uri': 'https://ror.org/032db5x82'}],
#        'uri': 'https://orcid.org/0000-0002-1238-5257',
#        'first': {'name': 'Kofi-Kermit'}},
#       {'middle': {'name': 'S'},
#        'last': {'name': 'Segers'},
#        'curie': 'ORCID:0000-0003-1058-1569',
#        'name': 'Segers, Lauren S',
#        'affiliations': [{'curie': 'ROR:032db5x82',
#          'name': 'University of South Florida',
#          'description': 'Molecular Pharmacology and Physiology\nMorsani College of Medicine\nUniversity of South Florida\nTampa, FL',
#          'uri': 'https://ror.org/032db5x82'}],
#        'uri': 'https://orcid.org/0000-0003-1058-1569',
#        'first': {'name': 'Lauren'}},
#       {'middle': {'name': 'C'},
#        'last': {'name': 'Nuding'},
#        'name': 'Nuding, Sarah C.',
#        'affiliations': [{'curie': 'ROR:032db5x82',
#          'name': 'University of South Florida',
#          'description': 'Molecular Pharmacology and Physiology\nMorsani College of Medicine\nUniversity of South Florida\nTampa, FL',
#          'uri': 'https://ror.org/032db5x82'}],
#        'first': {'name': 'Sarah'}},
#       {'last': {'name': 'Gestreau'},
#        'curie': 'ORCID:0000-0001-5069-482X',
#        'name': 'Gestreau, Christian',
#        'affiliations': [{'curie': 'ROR:032db5x82',
#          'name': 'University of South Florida',
#          'description': 'Molecular Pharmacology and Physiology\nMorsani College of Medicine\nUniversity of South Florida\nTampa, FL;\nAix-Marseille Université: Marseille, FR',
#          'uri': 'https://ror.org/032db5x82'}],
#        'uri': 'https://orcid.org/0000-0001-5069-482X',
#        'first': {'name': 'Christian'}},
#       {'middle': {'name': 'A'},
#        'last': {'name': 'Alencar'},
#        'name': 'Alencar, Pierina A.',
#        'affiliations': [{'curie': 'ROR:032db5x82',
#          'name': 'University of South Florida',
#          'description': 'Molecular Pharmacology and Physiology\nMorsani College of Medicine\nUniversity of South Florida\nTampa, FL',
#          'uri': 'https://ror.org/032db5x82'}],
#        'first': {'name': 'Pierina'}},
#       {'middle': {'name': 'Dale'},
#        'last': {'name': 'Shuman'},
#        'name': 'Shuman, H. Dale',
#        'affiliations': [{'curie': 'ROR:032db5x82',
#          'name': 'University of South Florida',
#          'description': 'Molecular Pharmacology and Physiology\nMorsani College of Medicine\nUniversity of South Florida\nTampa, FL',
#          'uri': 'https://ror.org/032db5x82'}],
#        'first': {'name': 'H.'}},
#       {'last': {'name': "O'Connor"},
#        'name': "O'Connor, Russell",
#        'affiliations': [{'curie': 'ROR:032db5x82',
#          'name': 'University of South Florida',
#          'description': 'Molecular Pharmacology and Physiology\nMorsani College of Medicine\nUniversity of South Florida\nTampa, FL',
#          'uri': 'https://ror.org/032db5x82'}],
#        'first': {'name': 'Russell'}},
#       {'middle': {'name': 'G'},
#        'last': {'name': 'Lindsey'},
#        'name': 'Lindsey, Bruce G.',
#        'affiliations': [{'curie': 'ROR:032db5x82',
#          'name': 'University of South Florida',
#          'description': 'Department of Molecular Pharmacology and Physiology\nMorsani College of Medicine\nUniversity of South Florida\nTampa, FL',
#          'uri': 'https://ror.org/032db5x82'}],
#        'first': {'name': 'Bruce'}},
#       {'middle': {'name': 'C'},
#        'last': {'name': 'Bolser'},
#        'curie': 'ORCID:0000-0002-4577-8954',
#        'name': 'Bolser, Donald C.',
#        'affiliations': [{'curie': 'ROR:02y3ad647',
#          'name': 'University of Florida',
#          'description': 'Department of Physiological Sciences\nSchool of Veterinary Medicine\nUniversity of Florida\nGainesville, FL',
#          'uri': 'https://ror.org/02y3ad647'}],
#        'uri': 'https://orcid.org/0000-0002-4577-8954',
#        'first': {'name': 'Donald'}},
#       {'middle': {'name': 'W'},
#        'last': {'name': 'Davenport'},
#        'name': 'Davenport, Paul W.',
#        'affiliations': [{'curie': 'ROR:02y3ad647',
#          'name': 'University of Florida',
#          'description': 'Department of Physiological Sciences\nSchool of Veterinary Medicine\nUniversity of Florida\nGainesville, FL',
#          'uri': 'https://ror.org/02y3ad647'}],
#        'first': {'name': 'Paul'}},
#       {'last': {'name': 'Pitts'},
#        'curie': 'ORCID:0000-0001-9448-2175',
#        'name': 'Pitts, Teresa',
#        'affiliations': [{'curie': 'ROR:01ckdn478',
#          'name': 'University of Louisville',
#          'description': 'University of Louisville\nLouisville, KY',
#          'uri': 'https://ror.org/01ckdn478'}],
#        'uri': 'https://orcid.org/0000-0001-9448-2175',
#        'first': {'name': 'Teresa'}}],
#      'dates': {'created': {'timestamp': '2019-01-15T19:28:09,769087Z'},
#       'updated': [{'timestamp': '2023-03-16T18:13:49,759000Z'}]},
#      'pennsieve': {'files': {'count': '192'},
#       'records': {'count': '34'},
#       'organization': {'name': 'SPARC Consortium', 'identifier': '367'},
#       'updatedAt': {'timestamp': '2023-10-10T09:35:13.566628Z',
#        'epoch': '1696930513'},
#       'owner': {'orcid': {'identifier': '0000-0001-6582-1203'},
#        'identifier': '224',
#        'first': {'name': 'Kendall'},
#        'last': {'name': 'Morris'}},
#       'sponsorship': {'name': 'NIH SPARC Program',
#        'uri': 'https://assets.discover.pennsieve.io/dataset-assets/sponsorships/sparc_logo.svg',
#        'description': 'This dataset is part of the NIH SPARC program and available on the\xa0<a href=http://sparc.science/datasets/35>SPARC Portal</a><br><br> Prior to being open-sourced, Pennsieve was known as the Blackfynn platform'},
#       'arn': 'arn:aws:s3:::pennsieve-prod-discover-publish-use1/35/3/',
#       'createdAt': {'timestamp': '2020-03-02T20:37:45.459724Z',
#        'epoch': '1583181465'},
#       'uri': 's3://pennsieve-prod-discover-publish-use1/35/3/',
#       'status': 'PUBLISH_SUCCEEDED',
#       'name': 'Feline brainstem neuron extracellular potential recordings',
#       'banner': {'uri': 'https://assets.discover.pennsieve.io/dataset-assets/35/3/revisions/4/banner.jpg'},
#       'firstPublishedAt': {'timestamp': '2019-07-23T00:12:15.406482Z',
#        'epoch': '1563840735'},
#       'versionPublishedAt': {'timestamp': '2020-03-02T20:37:45.459724Z',
#        'epoch': '1583181465'},
#       'license': {'keyword': 'Creative Commons Attribution'},
#       'version': {'identifier': '3'},
#       'description': 'Simultaneously recorded cat brain stem neuron extracellular potential with nerve and sorted spike trains.',
#       'schemaVersion': {'identifier': '4.0'},
#       'embargo': {'keyword': 'false'},
#       'readme': {'uri': 'https://assets.discover.pennsieve.io/dataset-assets/35/3/revisions/4/readme.md'},
#       'sourceDataset': {'identifier': '96'},
#       'revisedAt': {'timestamp': '2022-06-28T18:22:04.527474Z',
#        'epoch': '1656440524'},
#       'revision': {'identifier': '4'},
#       'identifier': '35'},
#      'organisms': {'subject': [{'strain': {'name': 'domestic short hair'},
#         'species': {'originalName': 'Felis catus',
#          'curie': 'NCBITaxon:9685',
#          'name': 'Cat',
#          'matchingStatus': 'Exact Match',
#          'parents': [{'curie': 'ilx:0104147', 'name': 'Felis'},
#           {'curie': 'ilx:0104146', 'name': 'Felinae'},
#           {'curie': 'ilx:0104144', 'name': 'Felidae'},
#           {'curie': 'ilx:0104145', 'name': 'Feliformia'},
#           {'curie': 'ilx:0101675', 'name': 'Carnivora'},
#           {'curie': 'ilx:0106143', 'name': 'Laurasiatheria'},
#           {'curie': 'ilx:0103988', 'name': 'Eutheria'},
#           {'curie': 'ilx:0111679', 'name': 'Theria'},
#           {'curie': 'ilx:0106498', 'name': 'Mammal'},
#           {'curie': 'ilx:0100551', 'name': 'Amniota'},
#           {'curie': 'ilx:0111643', 'name': 'Tetrapoda'},
#           {'curie': 'ilx:0110340', 'name': 'Sarcopterygii'},
#           {'curie': 'ilx:0103987', 'name': 'Euteleostomi'},
#           {'curie': 'ilx:0111564', 'name': 'Teleostomi'},
#           {'curie': 'ilx:0104698', 'name': 'Gnathostomata'},
#           {'curie': 'ilx:0112412', 'name': 'Vertebrata'},
#           {'curie': 'ilx:0102612', 'name': 'Craniata'},
#           {'curie': 'ilx:0102135', 'name': 'Chordata'},
#           {'curie': 'ilx:0103158', 'name': 'Deuterostomia'},
#           {'curie': 'ilx:0102337', 'name': 'Coelomata'},
#           {'curie': 'ilx:0101278', 'name': 'Bilateria'},
#           {'curie': 'ilx:0103978', 'name': 'Eumetazoa'},
#           {'curie': 'ilx:0106844', 'name': 'Metazoa'},
#           {'curie': 'ilx:0103976', 'name': 'Eukaryota'},
#           {'curie': 'ilx:0108133', 'name': 'Organism'}]}}],
#       'primary': [{'species': {'originalName': 'Felis catus',
#          'curie': 'NCBITaxon:9685',
#          'name': 'Cat',
#          'matchingStatus': 'Exact Match',
#          'parents': [{'curie': 'ilx:0104147', 'name': 'Felis'},
#           {'curie': 'ilx:0104146', 'name': 'Felinae'},
#           {'curie': 'ilx:0104144', 'name': 'Felidae'},
#           {'curie': 'ilx:0104145', 'name': 'Feliformia'},
#           {'curie': 'ilx:0101675', 'name': 'Carnivora'},
#           {'curie': 'ilx:0106143', 'name': 'Laurasiatheria'},
#           {'curie': 'ilx:0103988', 'name': 'Eutheria'},
#           {'curie': 'ilx:0111679', 'name': 'Theria'},
#           {'curie': 'ilx:0106498', 'name': 'Mammal'},
#           {'curie': 'ilx:0100551', 'name': 'Amniota'},
#           {'curie': 'ilx:0111643', 'name': 'Tetrapoda'},
#           {'curie': 'ilx:0110340', 'name': 'Sarcopterygii'},
#           {'curie': 'ilx:0103987', 'name': 'Euteleostomi'},
#           {'curie': 'ilx:0111564', 'name': 'Teleostomi'},
#           {'curie': 'ilx:0104698', 'name': 'Gnathostomata'},
#           {'curie': 'ilx:0112412', 'name': 'Vertebrata'},
#           {'curie': 'ilx:0102612', 'name': 'Craniata'},
#           {'curie': 'ilx:0102135', 'name': 'Chordata'},
#           {'curie': 'ilx:0103158', 'name': 'Deuterostomia'},
#           {'curie': 'ilx:0102337', 'name': 'Coelomata'},
#           {'curie': 'ilx:0101278', 'name': 'Bilateria'},
#           {'curie': 'ilx:0103978', 'name': 'Eumetazoa'},
#           {'curie': 'ilx:0106844', 'name': 'Metazoa'},
#           {'curie': 'ilx:0103976', 'name': 'Eukaryota'},
#           {'curie': 'ilx:0108133', 'name': 'Organism'}]}}]},
#      'protocols': {'primary': [{'current': {'uri': 'https://www.protocols.io/view/morris-usf-lab-protocol-bci8iuhw'},
#         'curie': 'DOI:10.17504/protocols.io.bci8iuhw',
#         'name': 'Morris USF Lab protocol',
#         'api': {'uri': 'https://www.protocols.io/api/v4/protocols/33088'}},
#        {'current': {'uri': 'https://www.protocols.io/view/morris-usf-lab-protocol-wscfeaw'},
#         'api': {'uri': 'https://www.protocols.io/api/v4/protocols/18980'}}]},
#      'anatomy': {'organ': [{'originalName': 'brainstem',
#         'curie': 'UBERON:0002298',
#         'name': 'Brainstem',
#         'subcategory': [{'name': 'central nervous system.brainstem'}],
#         'category': [{'name': 'central nervous system'}],
#         'matchingStatus': 'Exact Match'}]},
#      'publications': {'originating': [{'curie': 'DOI:10.3389/fphys.2018.00785',
#         'name': 'Central Respiration and Mechanical Ventilation in the Gating of Swallow With Breathing',
#         'uri': 'https://doi.org/10.3389/fphys.2018.00785'}]},
#      'distributions': {'current': [{'uri': 'https://app.pennsieve.io/N:organization:618e8dd9-f8d2-4dc4-9abb-c6aaab2e78a0/datasets/N:dataset:0a5a2827-2b39-4085-87ea-2b7fbbe27cc8'}],
#       'api': [{'uri': 'https://api.pennsieve.io/datasets/N:dataset:0a5a2827-2b39-4085-87ea-2b7fbbe27cc8'}]},
#      'attributes': {'subject': {'sex': [{'value': 'female'},
#         {'value': 'male'}],
#        'ageCategory': [{'value': 'adult'}]}},
#      'object_id': '35',
#      'dataItem': {'dataTypes': ['item',
#        'supportingAwards',
#        'contributors',
#        'anatomy',
#        'dates',
#        'pennsieve',
#        'organisms',
#        'protocols',
#        'publications',
#        'distributions',
#        'attributes',
#        'object_id']},
#      'provenance': {'ingestMethod': 'WEB',
#       'ingestTarget': 'file:///var/data/data-cache/SCR_017041-SPARC_Datasets-KS/cleaned',
#       'filePattern': '^NORM-MANIFEST-NORM-PENNSIEVE-\\w{8}-\\w{4}-\\w{4}-\\w{4}-\\w{12}\\.json$',
#       'ingestTime': '20231107T211048+0000',
#       'creationDate': ['20231107T211048+0000'],
#       'docId': '654aa7d8705f530594a81001',
#       'primaryKey': 'N:dataset:0a5a2827-2b39-4085-87ea-2b7fbbe27cc8',
#       'lastSeenDate': '20231107T211048+0000'}}},
#    {'_index': 'scr_017041-sparc_algolia_pr-ks-2022jul26',
#     '_type': 'ks',
#     '_id': '261',
#     '_score': 1.0,
#     '_ignored': ['pennsieve.versionPublishedAt.timestamp',
#      'pennsieve.revisedAt.timestamp',
#      'dates.updated.timestamp',
#      'pennsieve.firstPublishedAt.timestamp',
#      'dates.created.timestamp',
#      'pennsieve.createdAt.timestamp',
#      'pennsieve.updatedAt.timestamp'],
#     '_source': {'item': {'types': [{'name': 'dataset', 'type': 'category'}],
#       'contentTypes': [{'curie': 'ilx:0381348', 'name': 'product'}],
#       'names': [{'nameType': 'Complete Data Set',
#         'name': 'Expression of molecular markers for SG neuronal subpopulations in 3 sympathetic ganglia'}],
#       'statistics': {'files': {'count': '144'},
#        'samples': {'count': '25'},
#        'directory': {'count': '61'},
#        'subjects': {'count': '4'},
#        'bytes': {'count': '464785871'}},
#       'keywords': [{'keyword': 'Sympathetic'},
#        {'keyword': 'Stellate Ganglia'},
#        {'keyword': 'RNAScope'},
#        {'keyword': 'smFISH'}],
#       'published': {'status': 'revision', 'boolean': 'true'},
#       'dataset': {'description': 'We used RNAScope, a single molecule fluorescent in situ hybridization (smFISH) method, to visualize the transcripts of putative molecular markers for subpopulations of SG neurons identified using scRNA seq. Data consist of 45 images (CZI format) of SG cryosections stained with different RNASCope probe combinations, acquired with a Zeiss 710 microscope. Average file size: 4.3 MB',
#        'name': 'Expression of molecular markers in subpopulations of mouse SG neurons using smFISH'},
#       'readme': {'description': '**Study Purpose:** Sympathetic regulation of peripheral organ function is achieved through the coordinated actions of secretomotor, vasomotor and erector sympathetic neurons, in a manner that is highly conserved across species. Functionally distinct classes of sympathetic neurons have been defined by their firing properties and the expression of different combinations of neurotransmitters and neuropeptides. The identification of unique molecular markers for these populations would open the door to the application of genetic tools to parse the actions of secretomotor, vasomotor and erector sympathetic neurons. Here we confirmed the specificity of the expression patterns of the marker genes identified in bioinformatic analyses of single cell RNA-Seq of mouse stellate ganglia (SG) by multiplex single molecule fluorescent in situ hybridization (smFISH) on SG cryosections.\n\n**Data Collection:** Data consists of 41 images (CZI format) of combinations of RNAScope probes marking distinct populations of SG neurons in C57BL6/J mice using a Zeiss LSM 710 inverted confocal microscope.\n\n**Primary Conclusion:** Expression of candidate markers for subpopulations of stellate ganglion neurons detected by smFISH closely matched the expression pattern predicted by the scRNA-Seq analyses.\n\n---\n\n**Curator\'s Notes**\n\n**Experimental Design:** Mouse ganglia were dissected, fixed in 4% PFA in 0.1M PB overnight at 4°C, washed with Phosphate Buffer Saline (PBS) at 4°C for at least 1 h and encased in Optimal Cutting Temperature compound (Tissue-Tek)  then cut into 10 μm cryo-sections on slides, and stored at -80°C. RNAscope single-molecule fluorescent in situ hybridization (smFISH) multiplex version was performed as instructed by Advanced Cell Diagnostics (ACDBio, Document Number 320293-USM) without modification. Expression patterns were visualized by confocal microscopy. \n\n**Completeness:** This dataset is a part of a larger study, " Expression of molecular markers for SG neuronal subpopulations in 3 sympathetic ganglia."\n\n**Subjects & Samples:** Male (n=3) and female (n=1) adult mice (RRID:IMSR_JAX:000664) were used in this study. \n\n**Primary vs derivative data:** Primary data is organized by the subject ID folders and sample ID subfolder. Each sample subfolder contains confocal images (CZI format). Image data in the derivative folder (JPEG2000 and OME-TIFF) was derived from primary images (.CZI).\n\n**Important Notes:** A complete list of molecular probes is shown in the associated protocol https://www.protocols.io/view/expression-of-molecular-markers-in-subpopulations-b62mrgc6/materials, and is available as a pdf file in the protocol folder in this dataset. \n\n\n\n'},
#       'name': 'Expression of molecular markers in subpopulations of mouse stellate ganglion neurons ',
#       'identifier': 'N:dataset:663d8eba-eb68-4fef-b9a0-ac51410b26d3',
#       'curie': 'DOI:10.26275/zly9-ow0w',
#       'modalities': [{'keyword': 'transcriptomics'},
#        {'keyword': 'spatial transcriptomics'}],
#       'description': 'Expression of molecular markers in subpopulations of mouse stellate ganglion neurons using single molecule FISH (RNAScope)',
#       'docid': '261'},
#      'supportingAwards': [{'identifier': 'OT2OD023853',
#        'agency': {'name': 'National Institutes of Health'}},
#       {'agency': {'name': 'NIH SPARC Program'}}],
#      'contributors': [{'last': {'name': 'Lee'},
#        'curie': 'ORCID:0000-0002-9113-6637',
#        'name': 'Lee, Seoeun',
#        'affiliations': [{'description': 'https://ror.org/00hj8s172'}],
#        'uri': 'https://orcid.org/0000-0002-9113-6637',
#        'first': {'name': 'Seoeun'}},
#       {'last': {'name': 'Lafond'},
#        'curie': 'ORCID:0000-0002-6919-1779',
#        'name': 'Lafond, Alexandre',
#        'affiliations': [{'description': 'https://ror.org/00hj8s172'}],
#        'uri': 'https://orcid.org/0000-0002-6919-1779',
#        'first': {'name': 'Alexandre'}},
#       {'middle': {'name': 'M'},
#        'last': {'name': 'Zeltser'},
#        'curie': 'ORCID:0000-0002-4330-6240',
#        'name': 'Zeltser, Lori M.',
#        'affiliations': [{'description': 'https://ror.org/00hj8s172'}],
#        'uri': 'https://orcid.org/0000-0002-4330-6240',
#        'first': {'name': 'Lori'}}],
#      'dates': {'created': {'timestamp': '2020-07-27T00:48:49,146067Z'},
#       'updated': [{'timestamp': '2023-05-12T20:11:15,946000Z'}]},
#      'pennsieve': {'files': {'count': '166'},
#       'records': {'count': '42'},
#       'organization': {'name': 'SPARC Consortium', 'identifier': '367'},
#       'updatedAt': {'timestamp': '2023-10-10T10:12:41.367569Z',
#        'epoch': '1696932761'},
#       'owner': {'orcid': {'identifier': '0000-0002-4330-6240'},
#        'identifier': '616',
#        'first': {'name': 'Lori'},
#        'last': {'name': 'Zeltser'}},
#       'arn': 'arn:aws:s3:::pennsieve-prod-discover-publish-use1/261/1/',
#       'createdAt': {'timestamp': '2022-07-14T21:07:47.213162Z',
#        'epoch': '1657832867'},
#       'uri': 's3://pennsieve-prod-discover-publish-use1/261/1/',
#       'status': 'PUBLISH_SUCCEEDED',
#       'name': 'Expression of molecular markers in subpopulations of mouse stellate ganglion neurons ',
#       'banner': {'uri': 'https://assets.discover.pennsieve.io/dataset-assets/261/1/revisions/2/banner.jpg'},
#       'firstPublishedAt': {'timestamp': '2022-07-14T21:07:47.199279Z',
#        'epoch': '1657832867'},
#       'versionPublishedAt': {'timestamp': '2022-07-14T21:07:47.213162Z',
#        'epoch': '1657832867'},
#       'license': {'keyword': 'Creative Commons Attribution'},
#       'version': {'identifier': '1'},
#       'description': 'Expression of molecular markers in subpopulations of mouse stellate ganglion neurons using single molecule FISH (RNAScope)',
#       'schemaVersion': {'identifier': '4.0'},
#       'embargo': {'keyword': 'false'},
#       'readme': {'uri': 'https://assets.discover.pennsieve.io/dataset-assets/261/1/revisions/2/readme.md'},
#       'sourceDataset': {'identifier': '776'},
#       'revisedAt': {'timestamp': '2022-07-26T22:27:17.487458Z',
#        'epoch': '1658874437'},
#       'revision': {'identifier': '2'},
#       'identifier': '261'},
#      'organisms': {'subject': [{'strain': {'name': 'C57BL/6J',
#          'uri': 'https://scicrunch.org/resolver/RRID:IMSR_JAX:000664',
#          'rrid': 'RRID:IMSR_JAX:000664'},
#         'species': {'originalName': 'Mus musculus',
#          'curie': 'NCBITaxon:10090',
#          'name': 'Mouse',
#          'matchingStatus': 'Exact Match',
#          'parents': [{'curie': 'ilx:0107206', 'name': 'Mus'},
#           {'curie': 'ilx:0107203', 'name': 'Murinae'},
#           {'curie': 'ilx:0107202', 'name': 'Muridae'},
#           {'curie': 'ilx:0110420', 'name': 'Sciurognathi'},
#           {'curie': 'ilx:0110175', 'name': 'Rodent'},
#           {'curie': 'ilx:0104651', 'name': 'Glires'},
#           {'curie': 'ilx:0103972', 'name': 'Euarchontoglires'},
#           {'curie': 'ilx:0103988', 'name': 'Eutheria'},
#           {'curie': 'ilx:0111679', 'name': 'Theria'},
#           {'curie': 'ilx:0106498', 'name': 'Mammal'},
#           {'curie': 'ilx:0100551', 'name': 'Amniota'},
#           {'curie': 'ilx:0111643', 'name': 'Tetrapoda'},
#           {'curie': 'ilx:0110340', 'name': 'Sarcopterygii'},
#           {'curie': 'ilx:0103987', 'name': 'Euteleostomi'},
#           {'curie': 'ilx:0111564', 'name': 'Teleostomi'},
#           {'curie': 'ilx:0104698', 'name': 'Gnathostomata'},
#           {'curie': 'ilx:0112412', 'name': 'Vertebrata'},
#           {'curie': 'ilx:0102612', 'name': 'Craniata'},
#           {'curie': 'ilx:0102135', 'name': 'Chordata'},
#           {'curie': 'ilx:0103158', 'name': 'Deuterostomia'},
#           {'curie': 'ilx:0102337', 'name': 'Coelomata'},
#           {'curie': 'ilx:0101278', 'name': 'Bilateria'},
#           {'curie': 'ilx:0103978', 'name': 'Eumetazoa'},
#           {'curie': 'ilx:0106844', 'name': 'Metazoa'},
#           {'curie': 'ilx:0103976', 'name': 'Eukaryota'},
#           {'curie': 'ilx:0108133', 'name': 'Organism'}]}}],
#       'sample': [{'strain': {'name': 'C57BL6/J'}}],
#       'primary': [{'species': {'originalName': 'Mus musculus',
#          'curie': 'NCBITaxon:10090',
#          'name': 'Mouse',
#          'matchingStatus': 'Exact Match',
#          'parents': [{'curie': 'ilx:0107206', 'name': 'Mus'},
#           {'curie': 'ilx:0107203', 'name': 'Murinae'},
#           {'curie': 'ilx:0107202', 'name': 'Muridae'},
#           {'curie': 'ilx:0110420', 'name': 'Sciurognathi'},
#           {'curie': 'ilx:0110175', 'name': 'Rodent'},
#           {'curie': 'ilx:0104651', 'name': 'Glires'},
#           {'curie': 'ilx:0103972', 'name': 'Euarchontoglires'},
#           {'curie': 'ilx:0103988', 'name': 'Eutheria'},
#           {'curie': 'ilx:0111679', 'name': 'Theria'},
#           {'curie': 'ilx:0106498', 'name': 'Mammal'},
#           {'curie': 'ilx:0100551', 'name': 'Amniota'},
#           {'curie': 'ilx:0111643', 'name': 'Tetrapoda'},
#           {'curie': 'ilx:0110340', 'name': 'Sarcopterygii'},
#           {'curie': 'ilx:0103987', 'name': 'Euteleostomi'},
#           {'curie': 'ilx:0111564', 'name': 'Teleostomi'},
#           {'curie': 'ilx:0104698', 'name': 'Gnathostomata'},
#           {'curie': 'ilx:0112412', 'name': 'Vertebrata'},
#           {'curie': 'ilx:0102612', 'name': 'Craniata'},
#           {'curie': 'ilx:0102135', 'name': 'Chordata'},
#           {'curie': 'ilx:0103158', 'name': 'Deuterostomia'},
#           {'curie': 'ilx:0102337', 'name': 'Coelomata'},
#           {'curie': 'ilx:0101278', 'name': 'Bilateria'},
#           {'curie': 'ilx:0103978', 'name': 'Eumetazoa'},
#           {'curie': 'ilx:0106844', 'name': 'Metazoa'},
#           {'curie': 'ilx:0103976', 'name': 'Eukaryota'},
#           {'curie': 'ilx:0108133', 'name': 'Organism'}]}}]},
#      'protocols': {'primary': [{'current': {'uri': 'https://www.protocols.io/view/expression-of-molecular-markers-in-subpopulations-b62mrgc6'},
#         'curie': 'DOI:10.17504/protocols.io.8epv592bdg1b/v1',
#         'name': 'Expression of molecular markers in subpopulations of mouse stellate ganglion neurons',
#         'api': {'uri': 'https://www.protocols.io/api/v4/protocols/60205'}}]},
#      'anatomy': {'organ': [{'curie': 'UBERON:0000013',
#         'name': 'sympathetic nervous system',
#         'subcategory': [{'name': 'peripheral nervous system.sympathetic nervous system'}],
#         'category': [{'name': 'peripheral nervous system'}],
#         'matchingStatus': 'Exact Match'},
#        {'curie': 'UBERON:0002441',
#         'name': 'cervicothoracic ganglion',
#         'subcategory': [{'name': 'nerves and ganglia.cervicothoracic ganglion'}],
#         'category': [{'name': 'nerves and ganglia'}],
#         'matchingStatus': 'Exact Match'}],
#       'specimenType': [{'name': 'Stellate Ganglia'}]},
#      'distributions': {'current': [{'uri': 'https://app.pennsieve.io/N:organization:618e8dd9-f8d2-4dc4-9abb-c6aaab2e78a0/datasets/N:dataset:663d8eba-eb68-4fef-b9a0-ac51410b26d3'}],
#       'api': [{'uri': 'https://api.pennsieve.io/datasets/N:dataset:663d8eba-eb68-4fef-b9a0-ac51410b26d3'}]},
#      'attributes': {'subject': {'sex': [{'value': 'male'},
#         {'value': 'female'}],
#        'ageCategory': [{'value': 'adult'}]},
#       'sample': {'specimen_type': [{'value': 'Stellate Ganglia'}]}},
#      'object_id': '261',
#      'dataItem': {'dataTypes': ['item',
#        'supportingAwards',
#        'contributors',
#        'anatomy',
#        'dates',
#        'pennsieve',
#        'organisms',
#        'protocols',
#        'distributions',
#        'attributes',
#        'object_id']},
#      'provenance': {'ingestMethod': 'WEB',
#       'ingestTarget': 'file:///var/data/data-cache/SCR_017041-SPARC_Datasets-KS/cleaned',
#       'filePattern': '^NORM-MANIFEST-NORM-PENNSIEVE-\\w{8}-\\w{4}-\\w{4}-\\w{4}-\\w{12}\\.json$',
#       'ingestTime': '20231107T211048+0000',
#       'creationDate': ['20231107T211048+0000'],
#       'docId': '654aa7d8705f530594a80ff1',
#       'primaryKey': 'N:dataset:663d8eba-eb68-4fef-b9a0-ac51410b26d3',
#       'lastSeenDate': '20231107T211048+0000'}}},
#    {'_index': 'scr_017041-sparc_algolia_pr-ks-2022jul26',
#     '_type': 'ks',
#     '_id': '342',
#     '_score': 1.0,
#     '_ignored': ['pennsieve.versionPublishedAt.timestamp',
#      'pennsieve.revisedAt.timestamp',
#      'dates.updated.timestamp',
#      'pennsieve.firstPublishedAt.timestamp',
#      'dates.created.timestamp',
#      'pennsieve.createdAt.timestamp',
#      'pennsieve.updatedAt.timestamp'],
#     '_source': {'item': {'types': [{'name': 'computational model',
#         'type': 'category'}],
#       'contentTypes': [{'curie': 'ilx:0381348', 'name': 'product'}],
#       'names': [{'nameType': 'Complete Data Set'}],
#       'statistics': {'files': {'count': '4'},
#        'directory': {'count': '0'},
#        'bytes': {'count': '26829'}},
#       'keywords': [{'keyword': 'Flatmap'},
#        {'keyword': 'tutorial'},
#        {'keyword': 'oSPARC'}],
#       'published': {'status': 'publication', 'boolean': 'false'},
#       'dataset': {'description': 'SPARC has created detailed maps of the PNS, stored as flatmaps. However, the current interactivity possible with these flatmaps is basic and non-extensible. We use here ipyleaflet, a popular javascript library for adding interactive features to geographical maps to display and integrate flatmaps in Jupyter notebooks, popular for their use in scientific data analysis and computing. To allow for easier use by other, we also built a new python library called Sparclet. Not applicable, computational study SPARClet allows researchers much greater and extensible interactivity with SPARC flatmaps in an easy to use manner. These additional functionalities could help a researcher augment the research process and help in developing a deeper understanding of their field of study.',
#        'name': 'SPARClet - Interactive flatmaps'},
#       'readme': {'description': "**Study Purpose:** SPARC has created detailed maps of the PNS, stored as flatmaps. However, the current interactivity possible with these flatmaps is basic and non-extensible. We use here ipyleaflet, a popular javascript library for adding interactive features to geographical maps to display and integrate flatmaps in Jupyter notebooks, popular for their use in scientific data analysis and computing. To allow for easier use by other, we also built a new python library called *SPARClet*.\n\n**Data Collection:** Not applicable; computational study\n\n**Primary Conclusion:** *SPARClet* allows researchers much greater and extensible interactivity with SPARC flatmaps in an easy-to-use manner. These additional functionalities could help a researcher augment the research process and help in developing a deeper understanding of their field of study.\n\n---\n\n**Curator's Notes**\n\n**Experimental Design:** This project was developed during the 2022 [SPARC FAIR Codeathon](https://sparc.science/resources/1VmPvFmkyQrnnI4ZvjRxZH). Researchers created Sparclet, a pypi application that allows flatmaps to be viewed in Jupyter Notebook and be interacted in novel ways using the ipyleaflet library to help facilitate an individualized research process. \n\n**Completeness:** This dataset is complete.\n\n**Subjects & Samples:** This is a computational dataset; thus no subjects are described.\n\n**Primary vs derivative data:** Not applicable. This is a computational study. Only a configuration file to view and run the simulation on the oSPARC platform is provided.\n\n**Code Availability:** Source code available from https://github.com/SPARC-FAIR-Codeathon/SPARClet/\n"},
#       'name': 'SPARClet - Interactive flatmaps',
#       'identifier': 'N:dataset:e10f4df6-beda-4e4e-a08d-2f88b723cf92',
#       'curie': 'DOI:10.26275/nuwh-mtsd',
#       'modalities': [{'keyword': 'computational modeling'}],
#       'description': 'A python library to generate and interact with flatmaps in a jupyter notebook using the ipyleaflet library',
#       'docid': '342'},
#      'supportingAwards': [{'identifier': 'U18TR001920',
#        'agency': {'name': 'National Institutes of Health'}},
#       {'agency': {'name': 'NIH SPARC Program'}}],
#      'contributors': [{'last': {'name': 'Hoff'},
#        'name': 'Hoff, Chloe',
#        'affiliations': [{'description': 'University of Vermont'}],
#        'first': {'name': 'Chloe'}},
#       {'last': {'name': 'Bhatnagar'},
#        'name': 'Bhatnagar, Archit',
#        'affiliations': [{'description': 'Max Planck Institute of Molecular Cell Biology and Genetics, Dresden'}],
#        'first': {'name': 'Archit'}},
#       {'last': {'name': 'Sudarshan'},
#        'curie': 'ORCID:0000-0002-1256-1169',
#        'name': 'Sudarshan, Koustubh',
#        'affiliations': [{'description': 'Dalhousie University, Canada & UCLA Cardiac Arrhythmia Center, USA'}],
#        'uri': 'https://orcid.org/0000-0002-1256-1169',
#        'first': {'name': 'Koustubh'}},
#       {'last': {'name': 'Iavarone'},
#        'curie': 'ORCID:0000-0001-5157-247X',
#        'name': 'Iavarone, Elisabetta',
#        'affiliations': [{'description': 'IT’IS Foundation'}],
#        'uri': 'https://orcid.org/0000-0001-5157-247X',
#        'first': {'name': 'Elisabetta'}}],
#      'dates': {'created': {'timestamp': '2023-05-09T08:49:55,149997Z'},
#       'updated': [{'timestamp': '2023-10-04T01:05:45,794687Z'}]},
#      'pennsieve': {'files': {'count': '10'},
#       'records': {'count': '0'},
#       'organization': {'name': 'SPARC', 'identifier': '367'},
#       'updatedAt': {'timestamp': '2023-10-10T09:59:39.9526Z',
#        'epoch': '1696931979'},
#       'owner': {'orcid': {'identifier': '0000-0001-5157-247X'},
#        'identifier': '1230',
#        'first': {'name': 'Elisabetta'},
#        'last': {'name': 'Iavarone'}},
#       'collections': [{'identifier': '365',
#         'name': 'SPARC FAIR Codeathon 2022'}],
#       'arn': 'arn:aws:s3:::prd-sparc-discover-use1/342/1/',
#       'createdAt': {'timestamp': '2023-10-04T01:07:58.959616Z',
#        'epoch': '1696381678'},
#       'uri': 's3://prd-sparc-discover-use1/342/1/',
#       'status': 'PUBLISH_SUCCEEDED',
#       'name': 'SPARClet - Interactive flatmaps',
#       'banner': {'uri': 'https://assets.discover.pennsieve.io/dataset-assets/342/1/banner.jpg'},
#       'firstPublishedAt': {'timestamp': '2023-10-04T01:07:58.951837Z',
#        'epoch': '1696381678'},
#       'versionPublishedAt': {'timestamp': '2023-10-04T01:07:58.959616Z',
#        'epoch': '1696381678'},
#       'license': {'keyword': 'GNU Lesser General Public License'},
#       'version': {'identifier': '1'},
#       'description': 'A python library to generate and interact with flatmaps in a jupyter notebook using the ipyleaflet library',
#       'schemaVersion': {'identifier': '4.0'},
#       'embargo': {'keyword': 'false'},
#       'readme': {'uri': 'https://assets.discover.pennsieve.io/dataset-assets/342/1/readme.md'},
#       'sourceDataset': {'identifier': '2573'},
#       'revisedAt': {'timestamp': '', 'epoch': ''},
#       'revision': {'identifier': ''},
#       'identifier': '342'},
#      'distributions': {'current': [{'uri': 'https://app.pennsieve.io/N:organization:618e8dd9-f8d2-4dc4-9abb-c6aaab2e78a0/datasets/N:dataset:e10f4df6-beda-4e4e-a08d-2f88b723cf92'}],
#       'api': [{'uri': 'https://api.pennsieve.io/datasets/N:dataset:e10f4df6-beda-4e4e-a08d-2f88b723cf92'}]},
#      'object_id': '342',
#      'dataItem': {'dataTypes': ['item',
#        'supportingAwards',
#        'contributors',
#        'dates',
#        'pennsieve',
#        'distributions',
#        'object_id']},
#      'provenance': {'ingestMethod': 'WEB',
#       'ingestTarget': 'file:///var/data/data-cache/SCR_017041-SPARC_Datasets-KS/cleaned',
#       'filePattern': '^NORM-MANIFEST-NORM-PENNSIEVE-\\w{8}-\\w{4}-\\w{4}-\\w{4}-\\w{12}\\.json$',
#       'ingestTime': '20231107T211048+0000',
#       'creationDate': ['20231107T211048+0000'],
#       'docId': '654aa7d8705f530594a81017',
#       'primaryKey': 'N:dataset:e10f4df6-beda-4e4e-a08d-2f88b723cf92',
#       'lastSeenDate': '20231107T211048+0000'}}},
#    {'_index': 'scr_017041-sparc_algolia_pr-ks-2022jul26',
#     '_type': 'ks',
#     '_id': '112',
#     '_score': 1.0,
#     '_ignored': ['pennsieve.versionPublishedAt.timestamp',
#      'pennsieve.revisedAt.timestamp',
#      'dates.updated.timestamp',
#      'pennsieve.firstPublishedAt.timestamp',
#      'dates.created.timestamp',
#      'pennsieve.createdAt.timestamp',
#      'pennsieve.updatedAt.timestamp'],
#     '_source': {'item': {'types': [{'name': 'scaffold', 'type': 'category'}],
#       'contentTypes': [{'curie': 'ilx:0381348', 'name': 'product'}],
#       'names': [{'nameType': 'Complete Data Set',
#         'name': 'Rat whole-body scaffold'}],
#       'statistics': {'files': {'count': '28'},
#        'directory': {'count': '3'},
#        'bytes': {'count': '8888915'}},
#       'keywords': [{'keyword': 'whole body'},
#        {'keyword': 'abdomen'},
#        {'keyword': 'thorax'},
#        {'keyword': 'head'},
#        {'keyword': 'spinal cord'},
#        {'keyword': 'rat'}],
#       'published': {'status': 'publication', 'boolean': 'true'},
#       'dataset': {'description': 'Annotated rat whole body scaffold (abdomen, diaphragm, thorax, neck, head, skin, spinal cord) with embedded vagus nerves',
#        'name': 'Rat whole-body scaffold'},
#       'readme': {'description': '**Study Purpose:** The goal of this work is to create an annotated rat whole-body scaffold with embedded vagus nerves.\n\n**Data Collection:** The generic scaffold is created based on the generic body coordinates that fit data for the rat whole-body.\n\n**Primary Conclusion:** None stated\n\n---\n\n**Curator’s Notes**\n\n**Experimental Design:** Not applicable.\n\n**Completeness:** The study is ongoing and potentially will link to other datasets where the data is used for mapping onto the scaffold.\n\n**Subjects & Samples:** The body scaffold is not subject/sample-specific but the morphed scaffold was fitted to the given data.\n\n**Primary vs derivative data:** In the primary folder, nodal information and element connectivity of the scaffold are formatted as an exf file. Using the commands in the cmgui file, the scaffold can be visualized using open source software CMGUI. The primary folder also contains a json file that contains parameter settings to reproduce the scaffold in ScaffoldMaker. The derivative folder contains json files that are used to generate a visualization of the scaffold on the web portal.\n\n**Code Availability:** https://github.com/ABI-Software/scaffoldmaker (ABI-Software/scaffoldmaker Anatomical scaffold generator using OpenCMISS), https://models.physiomeproject.org/workspace/63a (scaffold source files)'},
#       'name': 'Rat whole-body scaffold',
#       'identifier': 'N:dataset:61be84f1-e010-43aa-8095-df791b887984',
#       'curie': 'DOI:10.26275/ffnm-sxbj',
#       'modalities': [{'keyword': 'computational modeling'},
#        {'keyword': 'scaffold'}],
#       'description': 'Annotated rat whole body scaffold (abdomen, diaphragm, thorax, neck, head, skin, spinal cord) with embedded vagus nerves.',
#       'docid': '112'},
#      'supportingAwards': [{'identifier': 'OT3OD025349',
#        'agency': {'name': 'National Institutes of Health'}},
#       {'agency': {'name': 'NIH SPARC Program'}}],
#      'contributors': [{'last': {'name': 'Christie'},
#        'curie': 'ORCID:0000-0003-4336-4640',
#        'name': 'Christie, Richard',
#        'affiliations': [{'description': 'Auckland Bioegineering Institute'}],
#        'uri': 'https://orcid.org/0000-0003-4336-4640',
#        'first': {'name': 'Richard'}},
#       {'last': {'name': 'Soltani'},
#        'curie': 'ORCID:0000-0003-2042-3783',
#        'name': 'Soltani, Elias',
#        'affiliations': [{'description': 'Auckland Bioegineering Institute'}],
#        'uri': 'https://orcid.org/0000-0003-2042-3783',
#        'first': {'name': 'Elias'}},
#       {'last': {'name': 'Hunter'},
#        'curie': 'ORCID:0000-0001-9665-4145',
#        'name': 'Hunter, Peter',
#        'affiliations': [{'description': 'Auckland Bioegineering Institute'}],
#        'uri': 'https://orcid.org/0000-0001-9665-4145',
#        'first': {'name': 'Peter'}}],
#      'dates': {'created': {'timestamp': '2021-01-20T21:22:28,705891Z'},
#       'updated': [{'timestamp': '2023-05-12T20:10:28,732000Z'}]},
#      'pennsieve': {'files': {'count': '42'},
#       'records': {'count': '13'},
#       'organization': {'name': 'SPARC Consortium', 'identifier': '367'},
#       'updatedAt': {'timestamp': '2023-10-10T10:18:21.442811Z',
#        'epoch': '1696933101'},
#       'owner': {'orcid': {'identifier': '0000-0003-2042-3783'},
#        'identifier': '1085',
#        'first': {'name': 'Elias'},
#        'last': {'name': 'Soltani'}},
#       'sponsorship': {'name': 'NIH SPARC Program',
#        'uri': 'https://assets.discover.pennsieve.io/dataset-assets/sponsorships/sparc_logo.svg',
#        'description': 'This dataset is part of the NIH SPARC program and available on the\xa0<a href=http://sparc.science/datasets/112>SPARC Portal</a><br><br> Prior to being open-sourced, Pennsieve was known as the Blackfynn platform'},
#       'arn': 'arn:aws:s3:::pennsieve-prod-discover-publish-use1/112/3/',
#       'createdAt': {'timestamp': '2022-12-16T02:45:42.401448Z',
#        'epoch': '1671158742'},
#       'uri': 's3://pennsieve-prod-discover-publish-use1/112/3/',
#       'status': 'PUBLISH_SUCCEEDED',
#       'name': 'Rat whole-body scaffold',
#       'banner': {'uri': 'https://assets.discover.pennsieve.io/dataset-assets/112/3/banner.jpg'},
#       'firstPublishedAt': {'timestamp': '2021-04-09T18:11:39.548549Z',
#        'epoch': '1617991899'},
#       'versionPublishedAt': {'timestamp': '2022-12-16T02:45:42.401448Z',
#        'epoch': '1671158742'},
#       'license': {'keyword': 'Creative Commons Attribution'},
#       'version': {'identifier': '3'},
#       'description': 'Annotated rat whole body scaffold (abdomen, diaphragm, thorax, neck, head, skin, spinal cord) with embedded vagus nerves.',
#       'schemaVersion': {'identifier': '4.0'},
#       'embargo': {'keyword': 'false'},
#       'readme': {'uri': 'https://assets.discover.pennsieve.io/dataset-assets/112/3/readme.md'},
#       'sourceDataset': {'identifier': '877'},
#       'revisedAt': {'timestamp': '', 'epoch': ''},
#       'revision': {'identifier': ''},
#       'identifier': '112'},
#      'anatomy': {'organ': [{'curie': 'UBERON:0013702',
#         'name': 'body proper',
#         'subcategory': [{'name': 'other.body proper'}],
#         'category': [{'name': 'other'}],
#         'matchingStatus': 'Exact Match'},
#        {'curie': 'UBERON:0001759',
#         'name': 'vagus nerve',
#         'subcategory': [{'name': 'nerves and ganglia.vagus nerve'}],
#         'category': [{'name': 'nerves and ganglia'}],
#         'matchingStatus': 'Exact Match'},
#        {'originalName': 'spinal cord',
#         'curie': 'UBERON:0002240',
#         'name': 'Spinal cord',
#         'subcategory': [{'name': 'central nervous system.spinal cord'}],
#         'category': [{'name': 'central nervous system'}],
#         'matchingStatus': 'Exact Match'},
#        {'curie': 'UBERON:0001003',
#         'name': 'skin epidermis',
#         'subcategory': [{'name': 'organ.skin epidermis'}],
#         'category': [{'name': 'organ'}],
#         'matchingStatus': 'Exact Match'},
#        {'originalName': 'diaphragm',
#         'curie': 'UBERON:0001103',
#         'name': 'Diaphragm',
#         'subcategory': [{'name': 'respiratory system.diaphragm'}],
#         'category': [{'name': 'respiratory system'}],
#         'matchingStatus': 'Exact Match'}]},
#      'distributions': {'current': [{'uri': 'https://app.pennsieve.io/N:organization:618e8dd9-f8d2-4dc4-9abb-c6aaab2e78a0/datasets/N:dataset:61be84f1-e010-43aa-8095-df791b887984'}],
#       'api': [{'uri': 'https://api.pennsieve.io/datasets/N:dataset:61be84f1-e010-43aa-8095-df791b887984'}]},
#      'object_id': '112',
#      'dataItem': {'dataTypes': ['item',
#        'supportingAwards',
#        'anatomy',
#        'contributors',
#        'dates',
#        'pennsieve',
#        'organisms',
# ...
#       'license': {'keyword': 'Creative Commons Attribution'},
#       'version': {'identifier': '1'},
#       'description': 'Partial dataset from published manuscript of same title.  Dataset includes intracellular recordings from control and diabetic mouse intrinsic cardiac neurons and stellate ganglion neurons.',
#       'schemaVersion': {'identifier': '4.0'},
#       'embargo': {'keyword': 'false'},
#       'readme': {'uri': 'https://assets.discover.pennsieve.io/dataset-assets/257/1/readme.md'},
#       'sourceDataset': {'identifier': '545'},
#       'revisedAt': {'timestamp': '', 'epoch': ''},
#       'revision': {'identifier': ''},
#       'identifier': '257'},
#      'organisms': {'subject': [{'strain': {'name': 'BKS.Cg-Dock7m+/+\xa0Leprdb/J, Jackson cat. no. 642',
#          'uri': 'https://scicrunch.org/resolver/RRID:IMSR_JAX:000642',
#          'rrid': 'RRID:IMSR_JAX:000642'},
#         'species': {'originalName': 'Mus musculus',
#          'curie': 'NCBITaxon:10090',
#          'name': 'Mouse',
#          'matchingStatus': 'Exact Match',
#          'parents': [{'curie': 'ilx:0107206', 'name': 'Mus'},
#           {'curie': 'ilx:0107203', 'name': 'Murinae'},
#           {'curie': 'ilx:0107202', 'name': 'Muridae'},
#           {'curie': 'ilx:0110420', 'name': 'Sciurognathi'},
#           {'curie': 'ilx:0110175', 'name': 'Rodent'},
#           {'curie': 'ilx:0104651', 'name': 'Glires'},
#           {'curie': 'ilx:0103972', 'name': 'Euarchontoglires'},
#           {'curie': 'ilx:0103988', 'name': 'Eutheria'},
#           {'curie': 'ilx:0111679', 'name': 'Theria'},
#           {'curie': 'ilx:0106498', 'name': 'Mammal'},
#           {'curie': 'ilx:0100551', 'name': 'Amniota'},
#           {'curie': 'ilx:0111643', 'name': 'Tetrapoda'},
#           {'curie': 'ilx:0110340', 'name': 'Sarcopterygii'},
#           {'curie': 'ilx:0103987', 'name': 'Euteleostomi'},
#           {'curie': 'ilx:0111564', 'name': 'Teleostomi'},
#           {'curie': 'ilx:0104698', 'name': 'Gnathostomata'},
#           {'curie': 'ilx:0112412', 'name': 'Vertebrata'},
#           {'curie': 'ilx:0102612', 'name': 'Craniata'},
#           {'curie': 'ilx:0102135', 'name': 'Chordata'},
#           {'curie': 'ilx:0103158', 'name': 'Deuterostomia'},
#           {'curie': 'ilx:0102337', 'name': 'Coelomata'},
#           {'curie': 'ilx:0101278', 'name': 'Bilateria'},
#           {'curie': 'ilx:0103978', 'name': 'Eumetazoa'},
#           {'curie': 'ilx:0106844', 'name': 'Metazoa'},
#           {'curie': 'ilx:0103976', 'name': 'Eukaryota'},
#           {'curie': 'ilx:0108133', 'name': 'Organism'}]}}],
#       'primary': [{'species': {'originalName': 'Mus musculus',
#          'curie': 'NCBITaxon:10090',
#          'name': 'Mouse',
#          'matchingStatus': 'Exact Match',
#          'parents': [{'curie': 'ilx:0107206', 'name': 'Mus'},
#           {'curie': 'ilx:0107203', 'name': 'Murinae'},
#           {'curie': 'ilx:0107202', 'name': 'Muridae'},
#           {'curie': 'ilx:0110420', 'name': 'Sciurognathi'},
#           {'curie': 'ilx:0110175', 'name': 'Rodent'},
#           {'curie': 'ilx:0104651', 'name': 'Glires'},
#           {'curie': 'ilx:0103972', 'name': 'Euarchontoglires'},
#           {'curie': 'ilx:0103988', 'name': 'Eutheria'},
#           {'curie': 'ilx:0111679', 'name': 'Theria'},
#           {'curie': 'ilx:0106498', 'name': 'Mammal'},
#           {'curie': 'ilx:0100551', 'name': 'Amniota'},
#           {'curie': 'ilx:0111643', 'name': 'Tetrapoda'},
#           {'curie': 'ilx:0110340', 'name': 'Sarcopterygii'},
#           {'curie': 'ilx:0103987', 'name': 'Euteleostomi'},
#           {'curie': 'ilx:0111564', 'name': 'Teleostomi'},
#           {'curie': 'ilx:0104698', 'name': 'Gnathostomata'},
#           {'curie': 'ilx:0112412', 'name': 'Vertebrata'},
#           {'curie': 'ilx:0102612', 'name': 'Craniata'},
#           {'curie': 'ilx:0102135', 'name': 'Chordata'},
#           {'curie': 'ilx:0103158', 'name': 'Deuterostomia'},
#           {'curie': 'ilx:0102337', 'name': 'Coelomata'},
#           {'curie': 'ilx:0101278', 'name': 'Bilateria'},
#           {'curie': 'ilx:0103978', 'name': 'Eumetazoa'},
#           {'curie': 'ilx:0106844', 'name': 'Metazoa'},
#           {'curie': 'ilx:0103976', 'name': 'Eukaryota'},
#           {'curie': 'ilx:0108133', 'name': 'Organism'}]}}]},
#      'protocols': {'primary': [{'current': {'uri': 'https://www.protocols.io/view/protocol-for-intracellular-recording-from-mouse-in-cczdsx26'},
#         'curie': 'DOI:10.17504/protocols.io.81wgb6ep3lpk/v1',
#         'name': 'Protocol for intracellular recording from mouse intrinsic cardiac neurons',
#         'api': {'uri': 'https://www.protocols.io/api/v4/protocols/66309'}}]},
#      'anatomy': {'organ': [{'curie': 'UBERON:0000948',
#         'name': 'heart',
#         'subcategory': [{'name': 'cardiovascular system.heart'},
#          {'name': 'organ.heart'}],
#         'category': [{'name': 'cardiovascular system'}, {'name': 'organ'}],
#         'matchingStatus': 'Exact Match'},
#        {'curie': 'UBERON:0002441',
#         'name': 'cervicothoracic ganglion',
#         'subcategory': [{'name': 'nerves and ganglia.cervicothoracic ganglion'}],
#         'category': [{'name': 'nerves and ganglia'}],
#         'matchingStatus': 'Exact Match'}]},
#      'distributions': {'current': [{'uri': 'https://app.pennsieve.io/N:organization:618e8dd9-f8d2-4dc4-9abb-c6aaab2e78a0/datasets/N:dataset:75eb4194-5ff8-4b88-a125-3c3dd23f9ef3'}],
#       'api': [{'uri': 'https://api.pennsieve.io/datasets/N:dataset:75eb4194-5ff8-4b88-a125-3c3dd23f9ef3'}]},
#      'attributes': {'subject': {'sex': [{'value': 'male'}],
#        'ageCategory': [{'value': 'adult'}]}},
#      'object_id': '257',
#      'dataItem': {'dataTypes': ['item',
#        'supportingAwards',
#        'contributors',
#        'anatomy',
#        'dates',
#        'pennsieve',
#        'organisms',
#        'protocols',
#        'distributions',
#        'attributes',
#        'object_id']},
#      'provenance': {'ingestMethod': 'WEB',
#       'ingestTarget': 'file:///var/data/data-cache/SCR_017041-SPARC_Datasets-KS/cleaned',
#       'filePattern': '^NORM-MANIFEST-NORM-PENNSIEVE-\\w{8}-\\w{4}-\\w{4}-\\w{4}-\\w{12}\\.json$',
#       'ingestTime': '20231107T211049+0000',
#       'creationDate': ['20231107T211049+0000'],
#       'docId': '654aa7d9705f530594a81048',
#       'primaryKey': 'N:dataset:75eb4194-5ff8-4b88-a125-3c3dd23f9ef3',
#       'lastSeenDate': '20231107T211049+0000'}}},
#    {'_index': 'scr_017041-sparc_algolia_pr-ks-2022jul26',
#     '_type': 'ks',
#     '_id': '136',
#     '_score': 1.0,
#     '_ignored': ['pennsieve.versionPublishedAt.timestamp',
#      'pennsieve.revisedAt.timestamp',
#      'dates.updated.timestamp',
#      'pennsieve.firstPublishedAt.timestamp',
#      'dates.created.timestamp',
#      'pennsieve.createdAt.timestamp',
#      'pennsieve.updatedAt.timestamp'],
#     '_source': {'item': {'types': [{'name': 'scaffold', 'type': 'category'}],
#       'contentTypes': [{'curie': 'ilx:0381348', 'name': 'product'}],
#       'names': [{'nameType': 'Complete Data Set',
#         'name': 'Generic human stomach scaffold'}],
#       'statistics': {'files': {'count': '22'},
#        'directory': {'count': '2'},
#        'bytes': {'count': '18655056'}},
#       'keywords': [{'keyword': 'stomach'},
#        {'keyword': 'human'},
#        {'keyword': 'myenteric plexus'}],
#       'published': {'status': 'publication', 'boolean': 'true'},
#       'dataset': {'description': 'Annotated stomach scaffold for human available for registration of segmented neural anatomical-functional mapping of enteric neural circuits.',
#        'name': 'Generic human stomach scaffold'},
#       'readme': {'description': '**Study Purpose:** The goal of this work is to create an annotated generic human stomach scaffold for the registration of segmented data obtained by experimental groups.\n\n**Data Collection:** An anatomically-based 3D scaffold of the human stomach is created to map nerve ending pathways. The stomach scaffold is generated with a configurable central path defined from the fundus apex to the duodenum. A user can annotate the fundus, body, antrum, pylorus, and duodenum along the central path and use that to define the respective regions of the stomach. The cross axes of the central path provide control of the major and minor radii of the stomach in different sections. The human stomach scaffold is parameterized with data to represent the anatomy as accurate as possible.\n\n**Primary Conclusion:** None stated\n\n---\n\n**Curator’s Notes**\n\n**Experimental Design:** Not applicable.\n\n**Completeness:** The study is ongoing and potentially will link to other datasets where the data is used for mapping onto the scaffold.\n\n**Subjects & Samples:** The generic scaffold is not subject/sample specific but represents an average stomach of subjects used in other studies.\n\n**Primary vs derivative data:** The primary folder contains the mapping tool provenance data file needed to produce the generic human stomach scaffold. The mapping tool will be accessible from the release download page on the SPARC Portal. The derivative folder contains JSON files which are used to generate a visualization of the scaffold on the web portal.\n\n**Code Availability:** https://github.com/ABI-Software/scaffoldmaker (ABI-Software/scaffoldmaker Anatomical scaffold generator using OpenCMISS), https://models.physiomeproject.org/e/8f0 (scaffold source files)'},
#       'name': 'Generic human stomach scaffold',
#       'identifier': 'N:dataset:bf117c9a-36d4-49fc-9dad-3b8db8acbf81',
#       'curie': 'DOI:10.26275/d52i-yves',
#       'modalities': [{'keyword': 'computational modeling'},
#        {'keyword': 'scaffold'}],
#       'description': 'Annotated human stomach scaffold available for registration of segmented neural anatomical-functional mapping of enteric neural circuits.',
#       'docid': '136'},
#      'supportingAwards': [{'identifier': 'OT3OD025349',
#        'agency': {'name': 'National Institutes of Health'}},
#       {'agency': {'name': 'NIH SPARC Program'}}],
#      'contributors': [{'last': {'name': 'Lin'},
#        'curie': 'ORCID:0000-0002-6388-2181',
#        'name': 'Lin, Mabelle',
#        'affiliations': [{'description': 'Auckland Bioegineering Institute'}],
#        'uri': 'https://orcid.org/0000-0002-6388-2181',
#        'first': {'name': 'Mabelle'}},
#       {'last': {'name': 'Christie'},
#        'curie': 'ORCID:0000-0003-4336-4640',
#        'name': 'Christie, Richard',
#        'affiliations': [{'description': 'Auckland Bioegineering Institute'}],
#        'uri': 'https://orcid.org/0000-0003-4336-4640',
#        'first': {'name': 'Richard'}},
#       {'last': {'name': 'Hunter'},
#        'curie': 'ORCID:0000-0001-9665-4145',
#        'name': 'Hunter, Peter',
#        'affiliations': [{'description': 'Auckland Bioegineering Institute'}],
#        'uri': 'https://orcid.org/0000-0001-9665-4145',
#        'first': {'name': 'Peter'}}],
#      'dates': {'created': {'timestamp': '2021-05-10T00:07:07,678516Z'},
#       'updated': [{'timestamp': '2023-05-12T20:28:10,833000Z'}]},
#      'pennsieve': {'files': {'count': '37'},
#       'records': {'count': '9'},
#       'organization': {'name': 'SPARC Consortium', 'identifier': '367'},
#       'updatedAt': {'timestamp': '2023-10-10T09:06:25.494861Z',
#        'epoch': '1696928785'},
#       'owner': {'orcid': {'identifier': '0000-0002-6388-2181'},
#        'identifier': '670',
#        'first': {'name': 'Mabelle'},
#        'last': {'name': 'Lin'}},
#       'sponsorship': {'name': 'NIH SPARC Program',
#        'uri': 'https://assets.discover.pennsieve.io/dataset-assets/sponsorships/sparc_logo.svg',
#        'description': 'This dataset is part of the NIH SPARC program and available on the\xa0<a href=http://sparc.science/datasets/136>SPARC Portal</a><br><br> Prior to being open-sourced, Pennsieve was known as the Blackfynn platform'},
#       'arn': 'arn:aws:s3:::pennsieve-prod-discover-publish-use1/136/4/',
#       'createdAt': {'timestamp': '2022-09-21T21:03:39.30337Z',
#        'epoch': '1663794219'},
#       'uri': 's3://pennsieve-prod-discover-publish-use1/136/4/',
#       'status': 'PUBLISH_SUCCEEDED',
#       'name': 'Generic human stomach scaffold',
#       'banner': {'uri': 'https://assets.discover.pennsieve.io/dataset-assets/136/4/banner.jpg'},
#       'firstPublishedAt': {'timestamp': '2021-05-10T22:02:50.127081Z',
#        'epoch': '1620684170'},
#       'versionPublishedAt': {'timestamp': '2022-09-21T21:03:39.30337Z',
#        'epoch': '1663794219'},
#       'license': {'keyword': 'Creative Commons Attribution'},
#       'version': {'identifier': '4'},
#       'description': 'Annotated human stomach scaffold available for registration of segmented neural anatomical-functional mapping of enteric neural circuits.',
#       'schemaVersion': {'identifier': '4.0'},
#       'embargo': {'keyword': 'false'},
#       'readme': {'uri': 'https://assets.discover.pennsieve.io/dataset-assets/136/4/readme.md'},
#       'sourceDataset': {'identifier': '968'},
#       'revisedAt': {'timestamp': '', 'epoch': ''},
#       'revision': {'identifier': ''},
#       'identifier': '136'},
#      'anatomy': {'organ': [{'curie': 'UBERON:0000945',
#         'name': 'stomach',
#         'subcategory': [{'name': 'digestive system.stomach'},
#          {'name': 'organ.stomach'}],
#         'category': [{'name': 'digestive system'}, {'name': 'organ'}],
#         'matchingStatus': 'Exact Match'}]},
#      'distributions': {'current': [{'uri': 'https://app.pennsieve.io/N:organization:618e8dd9-f8d2-4dc4-9abb-c6aaab2e78a0/datasets/N:dataset:bf117c9a-36d4-49fc-9dad-3b8db8acbf81'}],
#       'api': [{'uri': 'https://api.pennsieve.io/datasets/N:dataset:bf117c9a-36d4-49fc-9dad-3b8db8acbf81'}]},
#      'object_id': '136',
#      'dataItem': {'dataTypes': ['item',
#        'supportingAwards',
#        'anatomy',
#        'contributors',
#        'dates',
#        'pennsieve',
#        'organisms',
#        'distributions',
#        'object_id']},
#      'provenance': {'ingestMethod': 'WEB',
#       'ingestTarget': 'file:///var/data/data-cache/SCR_017041-SPARC_Datasets-KS/cleaned',
#       'filePattern': '^NORM-MANIFEST-NORM-PENNSIEVE-\\w{8}-\\w{4}-\\w{4}-\\w{4}-\\w{12}\\.json$',
#       'ingestTime': '20231107T211049+0000',
#       'creationDate': ['20231107T211049+0000'],
#       'docId': '654aa7d9705f530594a8104b',
#       'primaryKey': 'N:dataset:bf117c9a-36d4-49fc-9dad-3b8db8acbf81',
#       'lastSeenDate': '20231107T211049+0000'},
#      'organisms': {'primary': [{'species': {'originalName': 'Homo sapiens',
#          'curie': 'NCBITaxon:9606',
#          'name': 'Human',
#          'matchingStatus': 'Exact Match',
#          'parents': [{'curie': 'ilx:0105088', 'name': 'Homo'},
#           {'curie': 'ilx:0105089', 'name': 'Homo Pan Gorilla group'},
#           {'curie': 'ilx:0105086', 'name': 'Hominidae'},
#           {'curie': 'ilx:0105087', 'name': 'Hominoidea'},
#           {'curie': 'ilx:0101695', 'name': 'Catarrhini'},
#           {'curie': 'ilx:0110627', 'name': 'Simiiformes'},
#           {'curie': 'ilx:0104889', 'name': 'Haplorrhini'},
#           {'curie': 'ilx:0109341', 'name': 'Primate'},
#           {'curie': 'ilx:0103972', 'name': 'Euarchontoglires'},
#           {'curie': 'ilx:0103988', 'name': 'Eutheria'},
#           {'curie': 'ilx:0111679', 'name': 'Theria'},
#           {'curie': 'ilx:0106498', 'name': 'Mammal'},
#           {'curie': 'ilx:0100551', 'name': 'Amniota'},
#           {'curie': 'ilx:0111643', 'name': 'Tetrapoda'},
#           {'curie': 'ilx:0110340', 'name': 'Sarcopterygii'},
#           {'curie': 'ilx:0103987', 'name': 'Euteleostomi'},
#           {'curie': 'ilx:0111564', 'name': 'Teleostomi'},
#           {'curie': 'ilx:0104698', 'name': 'Gnathostomata'},
#           {'curie': 'ilx:0112412', 'name': 'Vertebrata'},
#           {'curie': 'ilx:0102612', 'name': 'Craniata'},
#           {'curie': 'ilx:0102135', 'name': 'Chordata'},
#           {'curie': 'ilx:0103158', 'name': 'Deuterostomia'},
#           {'curie': 'ilx:0102337', 'name': 'Coelomata'},
#           {'curie': 'ilx:0101278', 'name': 'Bilateria'},
#           {'curie': 'ilx:0103978', 'name': 'Eumetazoa'},
#           {'curie': 'ilx:0106844', 'name': 'Metazoa'},
#           {'curie': 'ilx:0103976', 'name': 'Eukaryota'},
#           {'curie': 'ilx:0108133', 'name': 'Organism'}]}}]}}}]}}

# %% [markdown]
# ## Search datasets via POST based query

# %% [markdown]
# The search is a basic search for dataset based on dataset identifier (in this example we will be retrieving SPARC datasets 10, 11, and 12 that are used in other sections of this tutorial).  The query is created as a JSON body that is submitted via POST. The dataset identifiers used in the example below refer to:
#
# 1. [Dataset with ID 10:](https://sparc.science/datasets/10?type=dataset) Spatial distribution and morphometric characterization of vagal afferents associated with the myenteric plexus of the rat stomach
# 2. [Dataset with ID 11:](https://sparc.science/datasets/11?type=dataset) Spatial distribution and morphometric characterization of vagal afferents (intramuscular arrays (IMAs)) within the longitudinal and circular muscle layers of the rat stomach
# 3. [Dataset with ID 12:](https://sparc.science/datasets/12?type=dataset) Spatial distribution and morphometric characterization of vagal efferents associated with the myenteric plexus of the rat stomach

# %%
# Set query as a JSON query string
response = {}
body = "{\"query\": {\"terms\": {\"_id\": [ \"10\", \"11\", \"12\" ] } } }"
body_json = json.loads(body)

# Get results from Elasticsearch
response = client.metadata.search_datasets(body_json)

# Check number of search hits available
number_of_records = response['hits']['total']
print('Number of records returned: ' + str(number_of_records))

# Can now process individual records as needed
# Out:
# Number of records returned: 3

# %% [markdown]
# You now are able to submit queries to the Elasticsearch endpoint.  As described above, you can refer to Elasticsearch documentation to generate queries for your specific use case.
