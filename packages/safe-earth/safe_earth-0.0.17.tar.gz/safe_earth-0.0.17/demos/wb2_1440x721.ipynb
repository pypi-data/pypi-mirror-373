# %%
# install the SAFE package
# !pip install safe-earth -q

# %%
import safe_earth as safe
import pandas as pd
import numpy as np
import pickle

# %%
from safe_earth.data.climate.era5 import ERA5Var

models = ['graphcast', 'pangu', 'fuxi']
resolution = '1440x721'
lead_times = [np.timedelta64(x, 'h') for x in range(24, 241, 24)]
variables = [ERA5Var('2m_temperature', name='T2M'), ERA5Var('total_precipitation_24hr', name='PR24')]
era5 = safe.data.climate.era5.get_era5(resolution, variables=variables)
data = []

# %%
era5
# Out:
# <xarray.Dataset> Size: 13GB
# Dimensions:    (time: 1505, latitude: 721, longitude: 1440)
# Coordinates:
#   * latitude   (latitude) float32 3kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude  (longitude) float32 6kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#   * time       (time) datetime64[ns] 12kB 2020-01-01 ... 2021-01-11
# Data variables:
#     T2M        (time, latitude, longitude) float32 6GB ...
#     PR24       (time, latitude, longitude) float32 6GB ...
